# %%
import numpy as np
import pandas as pd

# %%
df_bangalore=pd.read_csv("C:\\Users\\udaya\\Downloads\\archive (2)\\bengaluru.csv")

# %%
df_bangalore.head(6)
# Out:
#              date_time  maxtempC  mintempC  ...  visibility  winddirDegree  \
# 0  2009-01-01 00:00:00        27        12  ...          10            109
# 1  2009-01-01 01:00:00        27        12  ...           7             85
# 2  2009-01-01 02:00:00        27        12  ...           5             61
# 3  2009-01-01 03:00:00        27        12  ...           2             37
# 4  2009-01-01 04:00:00        27        12  ...           5             45
# 5  2009-01-01 05:00:00        27        12  ...           7             53
#
#    windspeedKmph
# 0              8
# 1              6
# 2              4
# 3              3
# 4              3
# 5              3
#
# [6 rows x 25 columns]

# %%
df_bangalore.tail(6)
# Out:
#                  date_time  maxtempC  mintempC  ...  visibility  \
# 96426  2020-01-01 18:00:00        26        18  ...          10
# 96427  2020-01-01 19:00:00        26        18  ...          10
# 96428  2020-01-01 20:00:00        26        18  ...           9
# 96429  2020-01-01 21:00:00        26        18  ...           9
# 96430  2020-01-01 22:00:00        26        18  ...          10
# 96431  2020-01-01 23:00:00        26        18  ...          10
#
#        winddirDegree  windspeedKmph
# 96426            108             15
# 96427            107             16
# 96428            106             16
# 96429            105             17
# 96430            106             16
# 96431            108             16
#
# [6 rows x 25 columns]

# %%
pd.set_option('display.max.columns',6)
pd.set_option('display.max.columns',6)
